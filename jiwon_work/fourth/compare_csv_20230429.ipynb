# %%
from compare_csv_fn_new import compare_with_sample_csv_fn
from compare_csv_fn_new import compare_with_prev_csv_fn

PREV_CSV_FILE_NAME = 'test_20230429_101620.csv'
CURRENT_CSV_FILE_NAME = 'baseline_submit.csv'

compare_with_sample_csv_fn('first', PREV_CSV_FILE_NAME)
compare_with_sample_csv_fn('second', CURRENT_CSV_FILE_NAME)

compare_with_prev_csv_fn('first', PREV_CSV_FILE_NAME, 'second', CURRENT_CSV_FILE_NAME)
# Out:
# compare_with_sample_csv_fn() : 322
# compare_with_sample_csv_fn() : 462
# 곰팡이 훼손
# 오염 몰딩수정
# 훼손 오염
# 훼손 오염
# 훼손 오염
# 훼손 몰딩수정
# 오타공 피스
# 걸레받이수정 훼손
# 훼손 오염
# 훼손 석고수정
# 훼손 걸레받이수정
# 훼손 오염
# 훼손 오염
# 꼬임 오염
# 훼손 오염
# 걸레받이수정 훼손
# 면불량 훼손
# 석고수정 터짐
# 훼손 곰팡이
# 훼손 오염
# 훼손 곰팡이
# 오염 오타공
# 걸레받이수정 몰딩수정
# 걸레받이수정 오염
# 꼬임 오염
# 몰딩수정 면불량
# 오타공 훼손
# 훼손 오염
# 훼손 걸레받이수정
# 훼손 오염
# 훼손 오염
# 훼손 오염
# 훼손 오염
# 오타공 훼손
# 오염 훼손
# 걸레받이수정 훼손
# 훼손 오염
# 훼손 몰딩수정
# 터짐 훼손
# 훼손 오염
# 훼손 오염
# 걸레받이수정 오염
# 오염 터짐
# 훼손 오염
# 몰딩수정 오염
# 훼손 오염
# 훼손 꼬임
# 오염 훼손
# 훼손 오염
# 훼손 걸레받이수정
# 훼손 오염
# 꼬임 면불량
# 오타공 훼손
# 꼬임 들뜸
# 훼손 터짐
# 훼손 오염
# 걸레받이수정 오염
# 훼손 오염
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 오타공 훼손
# 몰딩수정 터짐
# 오염 훼손
# 창틀,문틀수정 오염
# 훼손 몰딩수정
# 오염 터짐
# 오염 훼손
# 오염 훼손
# 훼손 오염
# 터짐 훼손
# 걸레받이수정 훼손
# 훼손 꼬임
# 오염 훼손
# 훼손 터짐
# 훼손 오염
# 훼손 꼬임
# 훼손 오염
# 훼손 면불량
# 훼손 오염
# 오염 훼손
# 오염 오타공
# 꼬임 훼손
# 훼손 오염
# 오염 훼손
# 오타공 훼손
# 피스 훼손
# 걸레받이수정 훼손
# 훼손 오염
# 꼬임 오염
# 훼손 오염
# 훼손 오염
# 오염 훼손
# 훼손 오염
# 오염 훼손
# 터짐 훼손
# 훼손 오염
# 걸레받이수정 꼬임
# 훼손 오염
# 터짐 오타공
# 오타공 훼손
# 훼손 꼬임
# 훼손 오염
# ...
