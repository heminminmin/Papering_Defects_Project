# %%
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import Xception
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense

# %%
# ========= 코드 그대로 모델 생성하고 학습시켜보기 =========
# https://techblog-history-younghunjo1.tistory.com/261

TRAIN_FOLDER_PATH = '../../open/train/'
TEST_FOLDER_PATH = '../../open/test/'

RESIZED_WIDTH = 10
RESIZED_HEIGHT = 10

train_img_generator = ImageDataGenerator(rescale=1/255.)
train_img_flow = train_img_generator.flow_from_directory(
    TRAIN_FOLDER_PATH, target_size=(RESIZED_WIDTH, RESIZED_HEIGHT))

# 추론 데이터 X
# test_img_generator = ImageDataGenerator(rescale=1/255.)
# test_img_flow = test_img_generator.flow_from_directory(
#     TRAIN_FOLDER_PATH, target_size=(RESIZED_WIDTH, RESIZED_HEIGHT))

# 2
print(len(train_img_flow))

# for img in train_img_flow:
#     print('img :', img)


def create_model_fn():

    input_tensor = Input(shape=(RESIZED_WIDTH, RESIZED_HEIGHT, 3))

    pretrained_model = Xception(
        input_tensor=input_tensor, include_top=False, weights='imagenet')
    pretrained_output = pretrained_model.output

    x = GlobalAveragePooling2D()(pretrained_output)
    x = Dense(units=128, activation='relu')(x)
    output = Dense(units=19, activation='softmax')(x)

    model = Model(inputs=input_tensor, outputs=output)
    model.summary()
    return model


model = create_model_fn()
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy', metrics=['acc'])

train_history = model.fit(train_img_flow, epochs=2)
loss = train_history.history['loss']
print('loss :', loss)

# ========================================================
# Out:
# Found 42 images belonging to 19 classes.
# 2
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 10, 10, 3)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 4, 4, 32)     864         ['input_4[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 4, 4, 32)    128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 4, 4, 32)     0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 2, 2, 64)     18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 2, 2, 64)    256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 2, 2, 64)     0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 2, 2, 128)   8768        ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 2, 2, 128)   512         ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 2, 2, 128)   0           ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 2, 2, 128)   17536       ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 2, 2, 128)   512         ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d_12 (Conv2D)             (None, 1, 1, 128)    8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 1, 1, 128)    0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 1, 1, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 1, 1, 128)    0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 1, 1, 128)   0           ['add_36[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 1, 1, 256)   33920       ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 1, 1, 256)   1024        ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 1, 1, 256)   0           ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 1, 1, 256)   67840       ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 1, 1, 256)   1024        ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_13 (Conv2D)             (None, 1, 1, 256)    32768       ['add_36[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 1, 1, 256)    0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  add_37 (Add)                   (None, 1, 1, 256)    0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 1, 1, 256)   0           ['add_37[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 1, 1, 728)   188672      ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_14 (Conv2D)             (None, 1, 1, 728)    186368      ['add_37[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 1, 1, 728)    0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 1, 1, 728)   2912        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_38 (Add)                   (None, 1, 1, 728)    0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 1, 1, 728)   0           ['add_38[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 1, 1, 728)   536536      ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 1, 1, 728)   0           ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 1, 1, 728)   536536      ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block5_sepconv3[0][0]']
#  lization)
#
#  add_39 (Add)                   (None, 1, 1, 728)    0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_38[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 1, 1, 728)   0           ['add_39[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 1, 1, 728)   536536      ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 1, 1, 728)   0           ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 1, 1, 728)   536536      ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block6_sepconv3[0][0]']
#  lization)
#
#  add_40 (Add)                   (None, 1, 1, 728)    0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_39[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 1, 1, 728)   0           ['add_40[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 1, 1, 728)   536536      ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 1, 1, 728)   0           ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 1, 1, 728)   536536      ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block7_sepconv3[0][0]']
#  lization)
#
#  add_41 (Add)                   (None, 1, 1, 728)    0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_40[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 1, 1, 728)   0           ['add_41[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 1, 1, 728)   536536      ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 1, 1, 728)   0           ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 1, 1, 728)   536536      ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block8_sepconv3[0][0]']
#  lization)
#
#  add_42 (Add)                   (None, 1, 1, 728)    0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_41[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 1, 1, 728)   0           ['add_42[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 1, 1, 728)   536536      ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 1, 1, 728)   0           ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 1, 1, 728)   536536      ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 1, 1, 728)   0           ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 1, 1, 728)   536536      ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 1, 1, 728)   2912        ['block9_sepconv3[0][0]']
#  lization)
#
#  add_43 (Add)                   (None, 1, 1, 728)    0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_42[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 1, 1, 728)   0           ['add_43[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 1, 1, 728)   536536      ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 1, 1, 728)   0           ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 1, 1, 728)   536536      ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 1, 1, 728)   0           ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 1, 1, 728)   536536      ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block10_sepconv3[0][0]']
#  alization)
#
#  add_44 (Add)                   (None, 1, 1, 728)    0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_43[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 1, 1, 728)   0           ['add_44[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 1, 1, 728)   536536      ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 1, 1, 728)   0           ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 1, 1, 728)   536536      ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 1, 1, 728)   0           ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 1, 1, 728)   536536      ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block11_sepconv3[0][0]']
#  alization)
#
#  add_45 (Add)                   (None, 1, 1, 728)    0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_44[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 1, 1, 728)   0           ['add_45[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 1, 1, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 1, 1, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 1, 1, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 1, 1, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 1, 1, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_46 (Add)                   (None, 1, 1, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_45[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 1, 1, 728)   0           ['add_46[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 1, 1, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 1, 1, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 1, 1, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 1, 1, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 1, 1, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_15 (Conv2D)             (None, 1, 1, 1024)   745472      ['add_46[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 1, 1, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_15[0][0]']
#  ormalization)
#
#  add_47 (Add)                   (None, 1, 1, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 1, 1, 1536)  1582080     ['add_47[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 1, 1, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 1, 1, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 1, 1, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 1, 1, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 1, 1, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_average_pooling2d_3 (Gl  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 128)          262272      ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_7 (Dense)                (None, 19)           2451        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 21,126,203
# Trainable params: 21,071,675
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# Epoch 1/2
# 2/2 [==============================] - 27s 2s/step - loss: 2.9515 - acc: 0.0238
# Epoch 2/2
# 2/2 [==============================] - 3s 587ms/step - loss: 2.9565 - acc: 0.0952
# loss : [2.951470375061035, 2.9564921855926514]
